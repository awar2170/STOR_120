# %% [markdown]
# # Homework 12: Classification

# %% [markdown]
# **Reading**:
#
# * [Classification](https://www.inferentialthinking.com/chapters/17/Classification.html)

# %% [markdown]
# Please complete this notebook by filling in the cells provided. Before you begin, execute the following cell.
#
# Directly sharing answers is not okay, but discussing problems with the course staff or with other students is encouraged.
#
# For all problems that you must write out explanations and sentences for, you **must** provide your answer in the designated space. Moreover, throughout this homework, please be sure to not re-assign variables throughout the notebook! For example, if you use `max_temperature` in your answer to one question, do not reassign it later on.

# %%
# Don't change this cell; just run it. 

import numpy as np
from datascience import *

# These lines do some fancy plotting magic.
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
import warnings
warnings.simplefilter('ignore', FutureWarning)

# %% [markdown]
# ## 1. Carolina vs Duke Fans by Location with Classification

# %% [markdown]
# Welcome to Homework 12! This homework is about k-Nearest Neighbors classification (kNN).

# %% [markdown]
# ## Our Dearest Neighbors

# %% [markdown]
# Dr McLean is trying classify residents of North Carolina as being fans of (or at least prefering) either the University of North Carolina at Chapel Hill or Duke. To classify the residents, Dr McLean has access to survey data containing the coordinates of the location where survey respondants live, as well as if they are fans of Carolina or Duke. First, load in the `coordinates` table.

# %%
# Future NOte: https://saravananthirumuruganathan.wordpress.com/2010/05/17/a-detailed-introduction-to-k-nearest-neighbor-knn-algorithm/

# %%
# Just run this cell!
coordinates = Table.read_table('../Datasets/coordinates.csv')
coordinates.show(5)
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>latitude</th> <th>longitude</th> <th>school</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>36.0158 </td> <td>-78.7698 </td> <td>Duke    </td>
#         </tr>
#         <tr>
#             <td>35.8757 </td> <td>-79.2824 </td> <td>Carolina</td>
#         </tr>
#         <tr>
#             <td>35.9113 </td> <td>-78.929  </td> <td>Carolina</td>
#         </tr>
#         <tr>
#             <td>35.9567 </td> <td>-78.9622 </td> <td>Carolina</td>
#         </tr>
#         <tr>
#             <td>35.9079 </td> <td>-79.0572 </td> <td>Duke    </td>
#         </tr>
#     </tbody>
# </table>
# <p>... (295 rows omitted)</p>

# %%
# Just run this cell!
coordinates = Table.read_table('coordinates.csv')
coordinates.show(5)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16640/3373647979.py in <module>
#       1 # Just run this cell!
# ----> 2 coordinates = Table.read_table('coordinates.csv')
#       3 coordinates.show(5)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\datascience\tables.py in read_table(cls, filepath_or_buffer, *args, **vargs)
#     143         except AttributeError:
#     144             pass
# --> 145         df = pandas.read_csv(filepath_or_buffer, *args, **vargs)
#     146         return cls.from_df(df)
#     147
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %% [markdown]
# As usual, let's investigate our data visually before performing any kind of numerical analysis.

# %%
# Just run this cell!
coordinates.scatter("longitude", "latitude", group="school")

# %% [markdown]
# Run the following cell to see what these points correspond to on a map.

# %%
# Just run this cell!
colors = {"Carolina":"lightblue", "Duke":"blue"}
t = Table().with_columns("lat", coordinates.column(0), 
                                      "lon", coordinates.column(1), 
                                      "color", coordinates.apply(colors.get, 2)
                        )
Circle.map_table(t, radius=5, fill_opacity=1)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %% [markdown]
# #### Question 1
#
# Let's begin implementing the k-Nearest Neighbors algorithm. Define the `distance` function, which takes in two arguments: an array of numerical features, and a different array of numerical features. The function should return the [Euclidean distance](https://en.wikipedia.org/wiki/Euclidean_distance) between the two arrays. Euclidean distance is often referred to as the straight-line distance formula that you may have learned previously.
#
#
# <!--
# BEGIN QUESTION
# name: q1_1
# manual: false
# -->

# %%
def distance(point1, point2):
    """Returns the distance between point1 and point2
    where each argument is an array 
    consisting of the coordinates of the point"""
    return np.sqrt(np.sum((point1 - point2)**2))

# Don't change/delete the code below in this cell
distance_example = distance(make_array(1, 2, 3), make_array(4, 5, 6))
distance_example
# Out:
# 5.196152422706632

# %% [markdown]
# ### Splitting the dataset
# We'll do 2 different kinds of things with the `coordinates` dataset:
# 1. We'll build a classifier using coordinates for which we know the associated label; this will teach it to recognize labels of similar coordinate values. This process is known as *training*.
# 2. We'll evaluate or *test* the accuracy of the classifier we build on data we haven't seen before.
#
# For reasons discussed in lecture and the textbook, we want to use separate datasets for these two purposes.  So we split up our one dataset into two.

# %% [markdown]
# #### Question 2
#
# Next, let's split our dataset into a training set and a test set. Since `coordinates` has $300$ rows, let's create a training set with 225 rows and a test set with the remaining 75 rows. Remember that assignment to each group should be random, so we should shuffle the table first.
#
# *Hint: as a first step we can shuffle all the rows, then use the* `tbl.take` *function to split up the rows for each table*
#
#
# <!--
# BEGIN QUESTION
# name: q1_2
# manual: false
# -->

# %%
# From the textbook, for reference
# shuffled_ckd = ckd.sample(with_replacement=False)
# training = shuffled_ckd.take(np.arange(79))
# testing = shuffled_ckd.take(np.arange(79, 158))

# %%
shuffled_table = coordinates.sample(with_replacement=False)
train = shuffled_table.take(np.arange(225))
test = shuffled_table.take(np.arange(75))

print("Training set:\t",   train.num_rows, "examples")
print("Test set:\t",       test.num_rows, "examples")
train.show(5), test.show(5);
# Out:
# Training set:	 225 examples
# Test set:	 75 examples
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>latitude</th> <th>longitude</th> <th>school</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>35.89   </td> <td>-79.1195 </td> <td>Carolina</td>
#         </tr>
#         <tr>
#             <td>35.8501 </td> <td>-79.1039 </td> <td>Carolina</td>
#         </tr>
#         <tr>
#             <td>36.1243 </td> <td>-79.1887 </td> <td>Carolina</td>
#         </tr>
#         <tr>
#             <td>35.8317 </td> <td>-79.1715 </td> <td>Carolina</td>
#         </tr>
#         <tr>
#             <td>36.2931 </td> <td>-79.3151 </td> <td>Duke    </td>
#         </tr>
#     </tbody>
# </table>
# <p>... (220 rows omitted)</p>
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>latitude</th> <th>longitude</th> <th>school</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
# ...

# %% [markdown]
# #### Question 3
#
# Assign `features` to an array of the labels of the features from the `coordinates` table.
#
# *Hint: which of the column labels in the `coordinates` table are the features, and which of the column labels correspond to the class we're trying to predict?*
#
# <!--
# BEGIN QUESTION
# name: q1_3
# manual: false
# -->

# %%
# make_array(coordinates["latitude"], coordinates["longitude"])

# %%
features = make_array(coordinates["latitude"], coordinates["longitude"])

# %% [markdown]
# #### Question 4
#
# Now define the `classify` function. This function should take in a `row` from a table like `test` and classify it based on the data in `train` using the `k`-Nearest Neighbors based on the correct `features`.
#
# *Hint: use the `row_to_array` function we defined for you to convert rows to arrays of features so that you can use the `distance` function you defined earlier.*
#
# *Hint 2: the skeleton code we provided iterates through each row in the training set*
#
# <!--
# BEGIN QUESTION
# name: q1_4
# manual: false
# -->

# %%
def all_distances(training, new_point):
    """Returns an array of distances
    between each point in the training set
    and the new point (which is a row of attributes)"""
    attributes = training
    def distance_from_point(row):
        return distance(np.array(new_point), np.array(row))
    return attributes.apply(distance_from_point)

def table_with_distances(training, new_point):
    """Augments the training table 
    with a column of distances from new_point"""
    return training.with_column('Distance', all_distances(training, new_point))

def closest(training, new_point, k):
    """Returns a table of the k rows of the augmented table
    corresponding to the k smallest distances"""
    with_dists = table_with_distances(training, new_point)
    sorted_by_distance = with_dists.sort('Distance')
    topk = sorted_by_distance.take(np.arange(k))
    return topk

def majority(topkclasses):
    ones = topkclasses.where('Class', are.equal_to(1)).num_rows
    zeros = topkclasses.where('Class', are.equal_to(0)).num_rows
    if ones > zeros:
        return 1
    else:
        return 0

def classify(training, new_point, k):
    closestk = closest(training, new_point, k)
    topkclasses = closestk.select('Class')
    return majority(topkclasses)

# %%
def row_to_array(row, features):
    return make_array(features[0][row], features[1][row])

# %%
from collections import Counter

# Goal 1: Get the distance between the test row and all of the training rows 

row = 0
train = train
k = 5

training_array = []
for x in np.arange(0,len(train["latitude"]), 1):
    value = row_to_array(x, train)
    training_array.append(value)
    
training_array

test_row_features_array = row_to_array(row, test)
test_row_features_array

def distance_array(x_1, y_1, x_2, y_2):
    return np.sqrt(((x_1 - x_2)**2) + ((y_1-y_2)**2))

# distance_array(test_row_features_array[0], test_row_features_array[1], training_array[1][0], training_array[1][1])

# Get the distance between the test row and all of the training rows 
distance_list = []

for x in np.arange(0, len(train["latitude"]), 1): 
    distance = distance_array(test_row_features_array[0], test_row_features_array[1], training_array[x][0], training_array[x][1])
    distance_list.append(distance)

# distance_list # This is the list of the distance between the test array in comparision to all of the training array points. 

train_with_distances = train.with_columns("Distances", distance_list)

c = Counter(train_with_distances["school"])
most_common_label = [k for k, v in c.items() if v == c.most_common(1)[0][1]]

most_common_label
# Out:
# ['Carolina']

# %%
# row = 0
# k = 5
# train = train 

# test_row_features_array = row_to_array(row, test)
# distances = make_array()
# for train_row in train.rows:
#     train_row_features_array = row_to_array(row, test_row_features_array)
#     row_distance = distance(train_row_features_array, test_row_features_array)
#     distances = np.append(distances, row_distance)
# train_with_distances = train.with_columns("Distances", distances)
# nearest_neighbors = min(train_with_distances["Distances"])
# c = Counter(train_with_distances["school"])
# most_common_label = [k for k, v in c.items() if v == c.most_common(1)[0][1]]

# most_common_label

# %%
# def row_to_array(row, features):
#     arr = make_array()
#     for feature in features:
#         arr = np.append(arr, row.item(feature))
#     return arr

def classify(row, k, train):
    training_array = []
    for x in np.arange(0,len(train["latitude"]), 1):
        value = row_to_array(x, train)
        training_array.append(value)

    training_array

    test_row_features_array = row_to_array(row, test)
    test_row_features_array

    def distance_array(x_1, y_1, x_2, y_2):
        return np.sqrt(((x_1 - x_2)**2) + ((y_1-y_2)**2))

    # distance_array(test_row_features_array[0], test_row_features_array[1], training_array[1][0], training_array[1][1])

    # Get the distance between the test row and all of the training rows 
    distance_list = []

    for x in np.arange(0, len(train["latitude"]), 1): 
        distance = distance_array(test_row_features_array[0], test_row_features_array[1], training_array[x][0], training_array[x][1])
        distance_list.append(distance)

    # distance_list # This is the list of the distance between the test array in comparision to all of the training array points. 

    train_with_distances = train.with_columns("Distances", distance_list)

    c = Counter(train_with_distances["school"])
    most_common_label = [k for k, v in c.items() if v == c.most_common(1)[0][1]]

    return most_common_label

# Don't modify/delete the code below
first_test = classify(0, 5, train)
first_test
# Out:
# ['Carolina']

# %% [markdown]
# #### Question 5
#
# Define the function `three_classify` that takes a `row` from `test` as an argument and classifies the row based on using 3-Nearest Neighbors. Use this function to find the `accuracy` of a 3-NN classifier on the `test` set. `accuracy` should be a proportion (not a percentage) of the schools that were correctly predicted.
#
# *Hint: you should be using a function you just created!*
#
# *Note: Usually before using a classifier on a test set, we'd classify first on a "validation" set, which we then can modify our training set again if need be, before actually testing on the test set. You don’t need to do that for this question, but you could learn about this more in later coursework.*
#
# <!--
# BEGIN QUESTION
# name: q1_5
# manual: false
# -->

# %%
def three_classify(row):
    return classify(row, 3, test)

values = []
for x in np.arange(0,len(test["school"]), 1):
    value = three_classify(x)
    values.append(value)
    
#values

# %%
def three_classify(row):
    return classify(row, 3, train)

test_with_prediction = test.with_column("prediction", values)

import numpy as np 

school_array = test_with_prediction["school"]
school_prop = np.unique(school_array, return_counts = True)
predict_array = test_with_prediction["prediction"]
predict_prop = np.unique(predict_array, return_counts=True)

print(school_prop)
print(predict_prop)

# 75 total, and all duke are wrong, so 55/75 are correct.

labels_correct = 55/75
accuracy = labels_correct
accuracy
# Out:
# 0.7333333333333333

# %% [markdown]
# #### Question 6
#
# There are 222 rows of Carolina fans and 78 rows of Duke fans in the `coordinates` table. If we used the entire `coordinates` table as the train set, what is the smallest value of k that would ensure that a k-Nearest Neighbor classifier would always predict Carolina as the class? Assign the value to `k`.
#
# <!--
# BEGIN QUESTION
# name: q1_6
# manual: false
# -->

# %%
train = coordinates
k = 0

training_array = []
for x in np.arange(0,len(train["latitude"]), 1):
    value = row_to_array(x, train)
    training_array.append(value)

training_array

test_row_features_array = row_to_array(row, test)
test_row_features_array

def distance_array(x_1, y_1, x_2, y_2):
    return np.sqrt(((x_1 - x_2)**2) + ((y_1-y_2)**2))

# distance_array(test_row_features_array[0], test_row_features_array[1], training_array[1][0], training_array[1][1])

# Get the distance between the test row and all of the training rows 
distance_list = []

for x in np.arange(0, len(train["latitude"]), 1): 
    distance = distance_array(test_row_features_array[0], test_row_features_array[1], training_array[x][0], training_array[x][1])
    distance_list.append(distance)

# distance_list # This is the list of the distance between the test array in comparision to all of the training array points. 

train_with_distances = train.with_columns("Distances", distance_list)

train_with_distances

c = Counter(train_with_distances["school"])
most_common_label = [k for k, v in c.items() if v == c.most_common(1)[0][1]]

most_common_label
# Out:
# ['Carolina']

# %%
k = 2
k
# Out:
# 2

# %% [markdown]
# #### Question 7
#
# Why do we use an odd-numbered `k` in k-NN? Explain.
#
#
# <!--
# BEGIN QUESTION
# name: q1_7
# manual: true
# -->
# <!-- EXPORT TO PDF -->

# %% [markdown]
# The textbook mentions that we can do this calculation on an even number of k, but then we would have to account for ties in the code.  Since we have not accounted for that in the code above, we have only used odds numbers going forward.

# %% [markdown]
# #### Question 8
#
# Dr McLean has devised a scheme for splitting up the test and training set. For each row from `coordinates`:
#
# - Rows for Duke fans have a 60% chance of being placed in the train set and 40% chance of placed in the test set.
#
# - Rows for Carolina fans have a 80% chance of being placed in the train set and 20% chance of placed in the test set.
#
#
# Given that a row is in the test set, what is the probability that it corresponds to a Duke fan? Assign that probability to `prob_dook`.
#
# *Hint: Remember that there are 222 Carolina fans and 78 Duke fans in `coordinates`*
#
# <!--
# BEGIN QUESTION
# name: q1_8
# manual: false
# -->

# %%
prob_dook = 0.5*0.4*(78/222)
prob_dook
# Out:
# 0.07027027027027027
